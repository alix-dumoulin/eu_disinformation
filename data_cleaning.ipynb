# %%
import json
import pandas as pd

with open('data/claims.json') as json_file:
    json_data = json.load(json_file)

# %%
data = pd.DataFrame(json_data)
data
# Out:
#                @id                    @type  \
# 0       /claims/36  http://schema.org/Claim
# 1       /claims/24  http://schema.org/Claim
# 2       /claims/22  http://schema.org/Claim
# 3       /claims/33  http://schema.org/Claim
# 4       /claims/21  http://schema.org/Claim
# ...            ...                      ...
# 7223  /claims/8385  http://schema.org/Claim
# 7224  /claims/8386  http://schema.org/Claim
# 7225  /claims/8387  http://schema.org/Claim
# 7226  /claims/8388  http://schema.org/Claim
# 7227  /claims/8389  http://schema.org/Claim
#
#                                             appearances  \
# 0                                  [/news_articles/196]
# 1                                  [/news_articles/126]
# 2                                  [/news_articles/123]
# 3                                  [/media_objects/173]
# 4                                  [/news_articles/122]
# ...                                                 ...
# ...

# %%
countries = data['contentLocations']
keys = data['keywords']

# %%
all_countries = list()
for i in countries:
    all_countries.extend(i)
all_countries
my_dict = {i:[] for i in all_countries}

# %%
# Out:
# {'/countries/4': [],
#  '/countries/9': [],
#  '/countries/20': [],
#  '/countries/24': [],
#  '/countries/8': [],
#  '/countries/11': [],
#  '/countries/14': [],
#  '/countries/3': [],
#  '/countries/25': [],
#  '/countries/28': [],
#  '/countries/29': [],
#  '/countries/26': [],
#  '/countries/19': [],
#  '/countries/37': [],
#  '/countries/40': [],
#  '/countries/41': [],
#  '/countries/42': [],
#  '/countries/43': [],
#  '/countries/44': [],
#  '/countries/45': [],
#  '/countries/46': [],
#  '/countries/47': [],
#  '/countries/48': [],
#  '/countries/17': [],
#  '/countries/36': [],
#  '/countries/49': [],
#  '/countries/50': [],
#  '/countries/18': [],
#  '/countries/31': [],
#  '/countries/51': [],
#  '/countries/52': [],
#  '/countries/30': [],
#  '/countries/53': [],
#  '/countries/15': [],
#  '/countries/13': [],
#  '/countries/35': [],
#  '/countries/56': [],
#  '/countries/59': [],
#  '/countries/60': [],
#  '/countries/61': [],
#  '/countries/57': [],
# ...

# %%
both = (countries, keys)

# %%
both[1][1]
# Out:
# ['/keywords/24', '/keywords/25', '/keywords/26']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-35a4b3da4621> in <module>
# ----> 1 {both[i][0]: both[i][1] for i in range(len(both[0]))}
#
# <ipython-input-30-35a4b3da4621> in <dictcomp>(.0)
# ----> 1 {both[i][0]: both[i][1] for i in range(len(both[0]))}
#
# TypeError: unhashable type: 'list'
